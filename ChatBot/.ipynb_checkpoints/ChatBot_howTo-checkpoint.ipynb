# %% [markdown]
# ### Intents.json – The data file which has predefined patterns and responses.
# ### train_chatbot.py – A script to build the model and train our chatbot.
# ### Words.pkl – Contains a list of our vocabulary.
# ### Classes.pkl – Contains the list of categories.
# ### Chatbot_model.h5 – Trained model (with model info like weights of the neurons).
# ### Chatgui.py – Script implementing GUI for our chatbot. Users can easily interact with the bot.

# %% [markdown]
# ## Import and load the data file
#
# The data file is in JSON format so we used the json package to parse the JSON file into Python.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('punkt') #needed for tokenizing classes (preprocessing)
nltk.download('wordnet') #needed for lemmatizing
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)
print(intents) #nice
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/ubuntu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 2021-09-23 13:15:52.696614: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-09-23 13:15:52.696650: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# {'intents': [{'tag': 'greeting', 'patterns': ['Hi there', 'How are you', 'Is anyone there?', 'Hey', 'Hola', 'Hello', 'Good day'], 'responses': ['Hello, thanks for asking', 'Good to see you again', 'Hi there, how can I help?'], 'context': ['']}, {'tag': 'goodbye', 'patterns': ['Bye', 'See you later', 'Goodbye', 'Nice chatting to you, bye', 'Till next time'], 'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'], 'context': ['']}, {'tag': 'thanks', 'patterns': ['Thanks', 'Thank you', "That's helpful", 'Awesome, thanks', 'Thanks for helping me'], 'responses': ['Happy to help!', 'Any time!', 'My pleasure'], 'context': ['']}, {'tag': 'noanswer', 'patterns': [], 'responses': ["Sorry, can't understand you", 'Please give me more info', 'Not sure I understand'], 'context': ['']}, {'tag': 'options', 'patterns': ['How you could help me?', 'What you can do?', 'What help you provide?', 'How you can be helpful?', 'What support is offered'], 'responses': ['I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies', 'Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies'], 'context': ['']}, {'tag': 'adverse_drug', 'patterns': ['How to check Adverse drug reaction?', 'Open adverse drugs module', 'Give me a list of drugs causing adverse behavior', 'List all drugs suitable for patient with adverse reaction', 'Which drugs dont have adverse reaction?'], 'responses': ['Navigating to Adverse drug reaction module'], 'context': ['']}, {'tag': 'blood_pressure', 'patterns': ['Open blood pressure module', 'Task related to blood pressure', 'Blood pressure data entry', 'I want to log blood pressure results', 'Blood pressure data management'], 'responses': ['Navigating to Blood Pressure module'], 'context': ['']}, {'tag': 'blood_pressure_search', 'patterns': ['I want to search for blood pressure result history', 'Blood pressure for patient', 'Load patient blood pressure result', 'Show blood pressure results for patient', 'Find blood pressure results by ID'], 'responses': ['Please provide Patient ID', 'Patient ID?'], 'context': ['search_blood_pressure_by_patient_id']}, {'tag': 'search_blood_pressure_by_patient_id', 'patterns': [], 'responses': ['Loading Blood pressure result for Patient'], 'context': ['']}, {'tag': 'pharmacy_search', 'patterns': ['Find me a pharmacy', 'Find pharmacy', 'List of pharmacies nearby', 'Locate pharmacy', 'Search pharmacy'], 'responses': ['Please provide pharmacy name'], 'context': ['search_pharmacy_by_name']}, {'tag': 'search_pharmacy_by_name', 'patterns': [], 'responses': ['Loading pharmacy details'], 'context': ['']}, {'tag': 'hospital_search', 'patterns': ['Lookup for hospital', 'Searching for hospital to transfer patient', 'I want to search hospital data', 'Hospital lookup for patient', 'Looking up hospital details'], 'responses': ['Please provide hospital name or location'], 'context': ['search_hospital_by_params']}, {'tag': 'search_hospital_by_params', 'patterns': [], 'responses': ['Please provide hospital type'], 'context': ['search_hospital_by_type']}, {'tag': 'search_hospital_by_type', 'patterns': [], 'responses': ['Loading hospital details'], 'context': ['']}]}

# %% [markdown]
# ## Preprocess data
#
# Tokenizing text data (basic first step) also create a list of classes for our tags.

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# ### lemmatize each word and remove duplicate words from the list
# #### lemmatize = sort words by grouping inflected or variant forms of the same word. nltk handles it

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ## Create training and testing data
#
#     Create the training data, we will provide the input and the output.
#     Input will be the pattern
#     Output will be the class that input pattern belongs to
#     Computer doesn’t understand text so we will convert text into numbers.

# %%
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training, dtype=object) #we are using tuples in the array so use object bc immutableness
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ## Build the model
#
#     We have our training data ready
#     now we will build a deep neural network that has 3 layers.
#     use the Keras sequential API

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# Epoch 1/200
# 2021-09-23 13:15:55.723681: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-09-23 13:15:55.723715: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-09-23 13:15:55.723737: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (CS): /proc/driver/nvidia/version does not exist
# 2021-09-23 13:15:55.723949: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ubuntu/anaconda3/envs/ML/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 2021-09-23 13:15:55.844934: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 10/10 [==============================] - 0s 2ms/step - loss: 2.2824 - accuracy: 0.0426
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1630 - accuracy: 0.1702
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.0196 - accuracy: 0.2128
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9925 - accuracy: 0.1915
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7982 - accuracy: 0.3830
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7626 - accuracy: 0.3617
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6061 - accuracy: 0.5319
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5188 - accuracy: 0.5532
# Epoch 9/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4011 - accuracy: 0.5957
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0900 - accuracy: 0.7872
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1851 - accuracy: 0.6170
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9533 - accuracy: 0.7872
# Epoch 13/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8971 - accuracy: 0.7660
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8567 - accuracy: 0.7872
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8197 - accuracy: 0.7660
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5566 - accuracy: 0.9362
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6723 - accuracy: 0.7872
# Epoch 18/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6128 - accuracy: 0.8723
# Epoch 19/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6895 - accuracy: 0.8511
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5224 - accuracy: 0.8511
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6502 - accuracy: 0.7872
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4849 - accuracy: 0.8511
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4934 - accuracy: 0.8085
# Epoch 24/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4174 - accuracy: 0.8936
# Epoch 25/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3941 - accuracy: 0.9149
# Epoch 26/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4144 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3630 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.8936
# Epoch 29/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3588 - accuracy: 0.8511
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.9149
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.8085
# Epoch 32/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3601 - accuracy: 0.8723
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1654 - accuracy: 0.9574
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2055 - accuracy: 0.9787
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1901 - accuracy: 0.9787
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2025 - accuracy: 0.9362
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1847 - accuracy: 0.9362
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2784 - accuracy: 0.9149
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1886 - accuracy: 0.9149
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.8936
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2048 - accuracy: 0.9149
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.8936
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3227 - accuracy: 0.9149
# Epoch 44/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1304 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0964 - accuracy: 0.9787
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1755 - accuracy: 0.9149
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1571 - accuracy: 0.9574
# Epoch 50/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1372 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1477 - accuracy: 0.9574
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1096 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.9574
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.9574
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1269 - accuracy: 0.9787
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0779 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1236 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1435 - accuracy: 0.9574
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1326 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9787
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0940 - accuracy: 0.9574
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.9574
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0411 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0746 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9787
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0914 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0470 - accuracy: 0.9787
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.9574
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1117 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9787
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1592 - accuracy: 0.9574
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.9574
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1388 - accuracy: 0.9362
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1023 - accuracy: 0.9574
# Epoch 97/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0471 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0666 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1084 - accuracy: 0.9574
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0515 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0659 - accuracy: 0.9574
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9787
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0621 - accuracy: 0.9787
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9787
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9787
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9787
# Epoch 116/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1132 - accuracy: 0.9362
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0807 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0909 - accuracy: 0.9574
# Epoch 120/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0489 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0576 - accuracy: 0.9787
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0440 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 0.9787
# Epoch 127/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9787
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9787
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9787
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9787
# Epoch 143/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0265 - accuracy: 0.9787
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0409 - accuracy: 0.9787
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9787
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0244 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.9574
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9787
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0265 - accuracy: 0.9787
# Epoch 178/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0442 - accuracy: 0.9787
# Epoch 182/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9787
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9787
# Epoch 185/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0689 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0258 - accuracy: 0.9787
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0513 - accuracy: 0.9787
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# model created

# %% [markdown]
# ### 200 epochs later, the accuracy regularly tests at 100% (on training data)

# %% [markdown]
# ## Predict the response
#
#     We will load the trained model, then use a GUI to predict the response from the bot.
#     model only tells us the class it belongs to
#     so we implement some functions to identify the class, then retrieve a random response from the list of responses.
#
#     import the necessary packages and load the ‘words.pkl’ and ‘classes.pkl’ pickle files which we have created when we trained our model:

# %%
#already made as .py's
# %run chatApp.py
# %run chatGUI.py
